# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
import pickle
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv("./credit.csv")

# %%
data
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
data["type"] = data["type"].map({ "PAYMENT": 2, 
                                 "CASH_IN": 3, "TRANSFER": 4,
                                 "DEBIT": 5})
data["isFraud"] = data["isFraud"].map({0: "No Fraud", 1: "Fraud"})
data = data.dropna()

# %%
x = np.array(data[["type", "amount", "oldbalanceOrg", "newbalanceOrig"]])
y = np.array(data[["isFraud"]])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
x_test
# Out:
# array([[2.00000000e+00, 5.13969000e+03, 0.00000000e+00, 0.00000000e+00],
#        [2.00000000e+00, 1.47896200e+04, 0.00000000e+00, 0.00000000e+00],
#        [3.00000000e+00, 2.50849590e+05, 7.04932303e+06, 7.30017261e+06],
#        ...,
#        [3.00000000e+00, 8.18278100e+04, 2.44920000e+04, 1.06319810e+05],
#        [3.00000000e+00, 4.74645500e+04, 3.67920000e+04, 8.42565500e+04],
#        [2.00000000e+00, 2.24705800e+04, 0.00000000e+00, 0.00000000e+00]])

# %%
model1 = DecisionTreeClassifier()
model1.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model2 = AdaBoostClassifier(estimator=DecisionTreeClassifier(), n_estimators=50, learning_rate=0.5)
model2.fit(x_train, y_train)
# Out:
# c:\Users\venky\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoostClassifier(estimator=DecisionTreeClassifier(), learning_rate=0.5)

# %%
from sklearn.neighbors import KNeighborsClassifier  
model3= KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2 )  
model3.fit(x_train, y_train)
# Out:
# c:\Users\venky\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
y_pred1 = model1.predict(x_test)
y_pred2 = model2.predict(x_test)
y_pred3 = model3.predict(x_test)

# %%
print("Decision Tree:",accuracy_score(y_pred1, y_test))
print("Adaptive Boost Classifier:", accuracy_score(y_pred2, y_test))
print("K Nearest Neighbours:", accuracy_score(y_pred2, y_test))
# Out:
# Decision Tree: 0.9998957606081762
# Adaptive Boost Classifier: 0.9999030331238848
# K Nearest Neighbours: 0.9999030331238848

# %%
pickle.dump(model1, open('DecisionTreeModel.pkl','wb'))
pickle.dump(model2, open('AdaptiveBoostModel.pkl','wb'))
pickle.dump(model3, open('KNNModel.pkl','wb'))
